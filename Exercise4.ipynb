# %% [markdown]
# # Exercise 4

# %%
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
import numpy as np
import pandas as pd

dataset = pd.read_json('reviews.json')

dataset.replace({1:0, 2:0,3:1,4:1,5:1}, inplace=True)
print("After Replacement:\n",dataset)

sentences = dataset['review'].tolist()
labels = dataset['rating'].tolist()



training_size = int(len(sentences) * 0.8)

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)
# Out:
# After Replacement:
#                                                   review  rating
# 0                       sir okay armygreen shorts nice        1
# 1     di pareha yong mga size nila may sobrang liit ...       1
# 2     super worth it ang ganda Sombra grabi order na...       1
# 3                                      ganda po salamat       1
# 4                   maayos pagkadeliver maganda den sya       1
# ...                                                 ...     ...
# 996   manipis siya masyado, tapos 9pcs lang yung isa...       0
# 997   maluwang and sobrang nipis. maluwang and sobra...       0
# 998   hope hindi tayo manloloko di ba???sa dami ng n...       0
# 999   Nakaka disappointed lng ng sobra sa seller .. ...       0
# 1000  salamat po sa courier pero Yung items po nakak...       0
#
# [1001 rows x 2 columns]

# %%
dataset.head()
# Out:
#                                               review  rating
# 0                    sir okay armygreen shorts nice        1
# 1  di pareha yong mga size nila may sobrang liit ...       1
# 2  super worth it ang ganda Sombra grabi order na...       1
# 3                                   ganda po salamat       1
# 4                maayos pagkadeliver maganda den sya       1

# %% [markdown]
# ## 1. Tokenize the data

# %%
vocab_size=400
oov_tok ="<OOV>"
tokenizer = Tokenizer(num_words = vocab_size,
                      oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
testing_sequences = tokenizer.texts_to_sequences(testing_sentences)

# %% [markdown]
# ## 2. Sequence the data

# %%
sequences = tokenizer.texts_to_sequences(training_sentences)
print (sequences)
# Out:
# [[1, 80, 1, 390, 66], [42, 1, 1, 63, 62, 219, 46, 89, 1, 1], [94, 126, 11, 9, 55, 1, 1, 24, 3, 100, 42, 100, 1, 1, 55, 24, 167, 54, 14, 9, 168, 38], [55, 21, 104], [119, 1, 23, 1, 22], [9, 1, 345, 1, 1, 345, 1, 5, 104, 44, 6, 41, 1, 9, 1, 180, 27, 15, 21, 220], [23, 22, 153, 127, 120, 12], [], [], [127, 1, 14, 1, 1, 1, 10, 1, 42, 23, 9, 1, 42, 1, 1, 91, 391, 91, 317, 1, 1, 10, 1], [1, 1], [1, 1, 47, 1, 1], [27, 15, 9, 55, 1, 167, 54, 10, 1, 35, 36, 272, 3, 114, 101, 1, 1], [30, 47, 14, 119, 17, 9, 1, 27, 15, 16], [55, 1, 12, 392, 167, 1, 5, 1, 33, 107, 28, 9, 55, 1, 1], [1, 1, 1], [9, 55, 1, 1, 25, 6, 1, 114, 25, 1, 9, 1, 77, 16, 14, 6, 1, 169, 115, 24, 167, 1], [40, 17, 7, 1, 1, 1, 3, 1, 253, 108, 12, 8, 127, 107, 22, 42, 393, 136, 6, 181, 195, 154, 1, 28, 40, 3, 22, 19, 2, 50, 108, 12, 17, 182, 1, 5, 12, 22, 10, 1, 1, 3], [4, 90, 2, 49, 4, 102, 11, 34, 81, 82, 89, 273, 10, 41, 1, 10, 1, 221, 38, 7, 24, 5, 221, 1], [140], [66, 394, 140], [23, 7, 47, 70, 1], [1, 1, 9, 63, 1, 1, 1, 395, 222, 100, 1, 1], [223, 290, 26, 4, 1, 45, 102, 92, 4, 396, 14, 2, 1, 291, 1, 1, 2, 62, 1, 21, 1, 237, 12, 46, 292, 107, 3, 62, 42, 5, 196, 9, 62, 1, 1, 1, 180], [1, 318, 24, 141, 1, 142, 318, 1, 1, 9, 1, 40, 3, 170, 397, 197, 1, 127, 58, 224, 28, 1, 1, 1, 37, 293, 142, 9, 1], [1, 24, 9, 274, 1, 9, 398, 3, 10, 130, 9, 398, 25, 107, 1, 1, 95, 107, 1], [109, 17, 1, 1, 23, 17, 21], [1, 1, 9, 63, 1, 1, 1, 395, 222, 100, 1, 1], [1, 24, 9, 274, 1, 9, 398, 3, 10, 1, 9, 398, 25, 107, 1, 1, 95, 107, 1], [109, 17, 1, 1, 23, 17, 21], [346, 196, 1, 1, 10, 108, 6, 1, 1, 1, 1, 3, 62, 162, 6, 1, 62, 1, 38], [27, 275, 16, 4, 1, 2, 75, 48, 1, 211, 1, 10, 32, 3, 86, 1, 10, 1, 1, 90, 11, 34, 81], [89, 143, 6, 399, 70, 3, 1, 3, 131, 1, 109, 1, 1, 10, 1, 347, 195, 1, 6, 63, 1, 348, 349, 212, 1, 144, 1, 24, 5, 3, 155, 104, 6, 1, 1], [1, 19, 36, 1, 1, 8, 96, 51, 4, 132, 1, 1, 1, 1, 1, 8, 29, 1, 1, 53, 163, 1, 1, 276, 1, 319, 1, 84, 39, 1], [40, 17, 1, 320, 12, 7, 121, 28, 1, 12, 1, 13, 1, 7, 1, 14, 1, 42, 5, 1, 197, 144, 1, 5, 1, 6, 213], [116, 3, 1, 9, 1, 9, 213, 1, 1, 30, 1, 1, 5, 1, 1, 1, 1, 1, 1, 1, 1, 1, 198, 220, 213, 8, 1], [143, 294, 321, 350], [351, 8, 1, 20, 1, 4, 74, 116, 2, 31, 8, 51, 27, 275, 1, 8, 76, 41, 64, 277], [295, 238, 1, 295, 1, 2, 1, 1, 239, 1, 171, 1, 133, 1, 1, 1, 8, 1, 24, 133, 1, 1, 131, 1, 1, 1, 8, 1, 1, 272, 41, 1, 272, 41, 1, 1, 1], [], [1, 199, 350, 26, 183, 1, 18, 1, 48, 36, 1, 1, 184, 18, 240, 2, 1, 1, 1, 130, 1, 1, 1, 352, 1, 65, 1, 84, 2, 1, 1, 4, 1, 3, 349, 172, 1, 1, 322, 9, 1, 26, 65, 1, 65, 2, 1, 13, 1, 84, 1, 1], [1, 43, 156, 29, 225, 1, 43, 65, 59, 1, 19, 2, 1, 1, 1, 1, 1, 254, 1, 1, 59, 1, 1, 65, 19, 1, 1, 1, 53, 1, 1, 4, 1, 1, 241, 1, 1, 2, 1, 53, 92, 4, 1, 74, 1, 77, 19, 1, 57, 242, 8, 1, 1, 5, 7, 4, 214, 27, 15, 19, 1, 1, 214, 1, 255, 14, 1, 8, 240, 133, 1, 1], [23, 23, 23, 23, 23, 23, 23, 23, 23, 23, 23], [394, 21, 22], [1, 1, 1, 1, 1], [137, 22, 8, 64, 353, 44, 1, 144, 1], [9, 55, 10, 32, 1, 64, 41, 25, 157, 9, 1, 25, 296, 256, 14, 41, 225, 323, 16, 17, 13, 1, 1], [30, 1], [66, 47, 8, 64, 243, 45, 52, 1, 50, 26, 297, 1, 1, 131, 128, 138, 243, 48, 215, 324, 1, 16], [20, 1, 21, 1, 3, 40, 17, 7, 243, 51, 1, 9, 1, 5, 12, 354, 317, 244, 1, 35, 278], [30, 47, 55, 10, 243, 1, 7, 1, 322, 71, 82, 1, 1, 7, 1, 1, 1, 1, 27, 275, 16], [1, 1, 21, 22, 257, 162, 6, 216, 3, 121, 7, 31, 1, 1, 1, 1, 22, 80, 355, 1, 356, 28, 1, 325, 21, 169, 1, 1, 10, 91, 1, 244, 258, 14, 1, 6, 259, 7, 169, 41, 21, 1, 1, 1, 7, 1], [42, 21, 22, 137, 185, 12, 294], [4, 238, 298, 39, 31, 1, 65, 15, 186, 326, 33, 1, 1, 6, 1, 1, 5, 223, 34, 1, 238, 1, 133, 327], [9, 357, 83, 10, 1, 1, 1, 37, 356, 1, 24, 1, 9, 55, 46, 1, 226, 87, 1, 83, 1, 37, 24, 141, 1, 83, 1, 215, 1, 9, 1, 1, 83], [42, 21, 22, 137, 185, 12, 294], [4, 238, 298, 39, 31, 1, 65, 15, 186, 326, 33, 1, 1, 6, 1, 1, 5, 223, 34, 1, 238, 1, 133, 327], [9, 357, 83, 10, 1, 1, 1, 37, 356, 1, 24, 1, 9, 55, 46, 1, 226, 87, 1, 83, 1, 37, 24, 141, 1, 83, 1, 215, 1, 9, 1, 1, 83], [23, 71, 64, 243, 1], [1, 1], [1,  ...

# %%
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

# %% [markdown]
# ## 3. Pad the data

# %%
max_length = 100
trunc_type='post'
padding_type='post'

padded = pad_sequences(sequences,maxlen=max_length, padding=padding_type,
                       truncating=trunc_type)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length,
                               padding=padding_type, truncating=trunc_type)

# %% [markdown]
# ## 4. Train a sentiment model

# %%
embedding_dim = 16
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(16, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 16)           6400
#
#  global_average_pooling1d (  (None, 16)                0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 32)                544
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 7489 (29.25 KB)
# Trainable params: 7489 (29.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
num_epochs = 35
model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Epoch 1/35
# 25/25 [==============================] - 10s 259ms/step - loss: 0.6746 - accuracy: 0.6888 - val_loss: 0.7395 - val_accuracy: 0.3234
# Epoch 2/35
# 25/25 [==============================] - 3s 122ms/step - loss: 0.6353 - accuracy: 0.6950 - val_loss: 0.8363 - val_accuracy: 0.3234
# Epoch 3/35
# 25/25 [==============================] - 2s 80ms/step - loss: 0.6143 - accuracy: 0.6950 - val_loss: 0.9316 - val_accuracy: 0.3234
# Epoch 4/35
# 25/25 [==============================] - 2s 75ms/step - loss: 0.6104 - accuracy: 0.6950 - val_loss: 0.9146 - val_accuracy: 0.3234
# Epoch 5/35
# 25/25 [==============================] - 1s 27ms/step - loss: 0.6077 - accuracy: 0.6950 - val_loss: 0.9313 - val_accuracy: 0.3234
# Epoch 6/35
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6047 - accuracy: 0.6950 - val_loss: 0.9206 - val_accuracy: 0.3234
# Epoch 7/35
# 25/25 [==============================] - 0s 19ms/step - loss: 0.6007 - accuracy: 0.6950 - val_loss: 0.8806 - val_accuracy: 0.3234
# Epoch 8/35
# 25/25 [==============================] - 0s 19ms/step - loss: 0.5948 - accuracy: 0.6950 - val_loss: 0.9118 - val_accuracy: 0.3234
# Epoch 9/35
# 25/25 [==============================] - 0s 13ms/step - loss: 0.5867 - accuracy: 0.6950 - val_loss: 0.8915 - val_accuracy: 0.3234
# Epoch 10/35
# 25/25 [==============================] - 1s 33ms/step - loss: 0.5737 - accuracy: 0.6950 - val_loss: 0.8606 - val_accuracy: 0.3234
# Epoch 11/35
# 25/25 [==============================] - 1s 51ms/step - loss: 0.5547 - accuracy: 0.6950 - val_loss: 0.8483 - val_accuracy: 0.3234
# Epoch 12/35
# 25/25 [==============================] - 1s 37ms/step - loss: 0.5255 - accuracy: 0.7025 - val_loss: 0.7514 - val_accuracy: 0.3682
# Epoch 13/35
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4824 - accuracy: 0.7563 - val_loss: 0.7677 - val_accuracy: 0.4080
# Epoch 14/35
# 25/25 [==============================] - 0s 15ms/step - loss: 0.4360 - accuracy: 0.8100 - val_loss: 0.7422 - val_accuracy: 0.4876
# Epoch 15/35
# 25/25 [==============================] - 2s 96ms/step - loss: 0.3961 - accuracy: 0.8313 - val_loss: 0.8735 - val_accuracy: 0.4478
# Epoch 16/35
# 25/25 [==============================] - 1s 44ms/step - loss: 0.3631 - accuracy: 0.8438 - val_loss: 0.7423 - val_accuracy: 0.5672
# Epoch 17/35
# 25/25 [==============================] - 1s 29ms/step - loss: 0.3295 - accuracy: 0.8637 - val_loss: 0.7345 - val_accuracy: 0.6020
# Epoch 18/35
# 25/25 [==============================] - 0s 18ms/step - loss: 0.3137 - accuracy: 0.8612 - val_loss: 0.7857 - val_accuracy: 0.5920
# Epoch 19/35
# 25/25 [==============================] - 0s 18ms/step - loss: 0.2943 - accuracy: 0.8763 - val_loss: 0.6286 - val_accuracy: 0.6816
# Epoch 20/35
# 25/25 [==============================] - 1s 39ms/step - loss: 0.2757 - accuracy: 0.8888 - val_loss: 0.8191 - val_accuracy: 0.6070
# Epoch 21/35
# 25/25 [==============================] - 1s 42ms/step - loss: 0.2686 - accuracy: 0.8863 - val_loss: 0.8262 - val_accuracy: 0.6269
# Epoch 22/35
# 25/25 [==============================] - 0s 6ms/step - loss: 0.2557 - accuracy: 0.8900 - val_loss: 0.8500 - val_accuracy: 0.6169
# Epoch 23/35
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2506 - accuracy: 0.8938 - val_loss: 0.7591 - val_accuracy: 0.6368
# Epoch 24/35
# 25/25 [==============================] - 0s 20ms/step - loss: 0.2485 - accuracy: 0.8850 - val_loss: 0.6212 - val_accuracy: 0.6866
# Epoch 25/35
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2324 - accuracy: 0.9013 - val_loss: 0.8922 - val_accuracy: 0.6070
# Epoch 26/35
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2282 - accuracy: 0.9050 - val_loss: 0.7943 - val_accuracy: 0.6368
# Epoch 27/35
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2173 - accuracy: 0.9100 - val_loss: 0.8158 - val_accuracy: 0.6368
# Epoch 28/35
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2105 - accuracy: 0.9175 - val_loss: 0.8397 - val_accuracy: 0.6368
# Epoch 29/35
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2040 - accuracy: 0.9200 - val_loss: 0.8712 - val_accuracy: 0.6269
# Epoch 30/35
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1980 - accuracy: 0.9175 - val_loss: 0.7968 - val_accuracy: 0.6617
# Epoch 31/35
# 25/25 [==============================] - 0s 7ms/step - loss: 0.1933 - accuracy: 0.9237 - val_loss: 0.8552 - val_accuracy: 0.6468
# Epoch 32/35
# 25/25 [==============================] - 0s 7ms/step - loss: 0.1895 - accuracy: 0.9225 - val_loss: 0.9362 - val_accuracy: 0.6119
# Epoch 33/35
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1872 - accuracy: 0.9237 - val_loss: 1.1172 - val_accuracy: 0.5821
# Epoch 34/35
# 25/25 [==============================] - 0s 7ms/step - loss: 0.2026 - accuracy: 0.9125 - val_loss: 0.9510 - val_accuracy: 0.6169
# Epoch 35/35
# 25/25 [==============================] - 0s 7ms/step - loss: 0.1739 - accuracy: 0.9262 - val_loss: 0.9550 - val_accuracy: 0.6169

# %% [markdown]
# ## Get files for visualing the network

# %%
# First get the weights of the embedding layer
e = model.layers[0]
weights = e.get_weights()[0]
print(weights.shape) # shape: (vocab_size, embedding_dim)
# Out:
# (400, 16)

# %%
import io

# Write out the embedding vectors and metadata
out_v = io.open('vecs.tsv', 'w', encoding='utf-8')
out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for word_num in range(1, vocab_size):
  word = reverse_word_index[word_num]
  embeddings = weights[word_num]
  out_m.write(word + "\n")
  out_v.write('\t'.join([str(x) for x in embeddings]) + "\n")
out_v.close()
out_m.close()

# %%
# Download the files
try:
  from google.colab import files
except ImportError:
  pass
else:
  files.download('vecs.tsv')
  files.download('meta.tsv')

# %% [markdown]
# ## 5. Predict sentiment with new reviews

# %%
fake_reviews = ['basura ung shorts',
                'Ang mahal tas ang panget',
                'lugi sa presyo','nice po ung armygreen',
                'tangina','punit ung shorts',
                'di legit ung seller',
                'tshirt dumating sakin di short',
                'tagal ng driver', 'worth it ung price',
                'bobo nyo', 'maganda ung shorts', 'sira ung box','ganda po salamat']

print(fake_reviews)

padding_type='post'
sample_sequences = tokenizer.texts_to_sequences(fake_reviews)
fakes_padded = pad_sequences(sample_sequences, padding=padding_type, maxlen=max_length)

print('\nHOT OFF THE PRESS! HERE ARE SOME NEWLY MINTED, ABSOLUTELY GENUINE REVIEWS!\n')

classes = model.predict(fakes_padded)


for x in range(len(fake_reviews)):
  print(fake_reviews[x])
  print(classes[x])
  print('\n')
# Out:
# ['basura ung shorts', 'Ang mahal tas ang panget', 'lugi sa presyo', 'nice po ung armygreen', 'tangina', 'punit ung shorts', 'di legit ung seller', 'tshirt dumating sakin di short', 'tagal ng driver', 'worth it ung price', 'bobo nyo', 'maganda ung shorts', 'sira ung box', 'ganda po salamat']
#
# HOT OFF THE PRESS! HERE ARE SOME NEWLY MINTED, ABSOLUTELY GENUINE REVIEWS!
#
# 1/1 [==============================] - 0s 95ms/step
# basura ung shorts
# [0.34198055]
#
#
# Ang mahal tas ang panget
# [0.55938303]
#
#
# lugi sa presyo
# [0.8242396]
#
#
# nice po ung armygreen
# [0.8825986]
#
#
# tangina
# [0.628571]
#
#
# punit ung shorts
# [0.34198055]
#
#
# di legit ung seller
# [0.2658982]
#
#
# tshirt dumating sakin di short
# [0.43202502]
#
#
# tagal ng driver
# [0.4552013]
#
#
# worth it ung price
# [0.44250584]
#
#
# bobo nyo
# [0.5862216]
#
#
# maganda ung shorts
# [0.5315215]
#
#
# sira ung box
# [0.5067301]
#
#
# ganda po salamat
# [0.9882705]
